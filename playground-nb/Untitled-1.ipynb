# %%
python version
# Out:
# Running cells with 'venv (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/sahilsingh/projects/mini-llm/venv/bin/python -m pip install ipykernel -U --force-reinstall'
